# %% [markdown]
# # Numpy

# %%
import numpy as np
import math

# %% [markdown]
# ##Numpy array

# %%
a = np.array([1, 2, 3])
print(a)
print(a.ndim)
# Out:
# [1 2 3]
# 1

# %%
b = np.array([[1, 2, 3], [4, 5, 6]])
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.dtype
# Out:
# dtype('int64')
