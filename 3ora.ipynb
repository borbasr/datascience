# %%
from tkinter.constants import FIRST

import numpy as np
import pandas as pd
from tornado.web import url

record1 = pd.Series({'Name': 'Alice', 'Class': 'Physics', 'Score': 85})
record2 = pd.Series({'Name': 'Jack', 'Class': 'Chemistry', 'Score': 82})
record3 = pd.Series({'Name': 'Helen', 'Class': 'Biology', 'Score': 90})

df = pd.DataFrame([record1, record2, record3], index=['school1', 'school2', 'school1'])
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
students = [
    {'Name': 'Alice', 'Class': 'Physics', 'Score': 85}
    {'Name': 'Jack', 'Class': 'Chemistry', 'Score': 82}
]

# %%
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
df.T.loc['Name']
# Out:
# school1    Alice
# school2     Jack
# school1    Helen
# Name: Name, dtype: object

# %%
df.loc['school1']['Score']
# Out:
# school1    85
# school1    90
# Name: Score, dtype: int64

# %%
df.loc['Name','Score']

# %% [markdown]
# ##DF indexing and Loading

# %%
df = pd.read_csv("mpg.csv")
df.head()
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
# 4           5         audi    a4    2.8  1999    6    auto(l5)   f   16   26
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact
# 4  p  compact

# %%
df = pd.read_csv("mpg.csv", index_col=0)
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
new_df = df.rename(columns= {'year': 'Év', 'cyl': 'Henger'})
new_df.head()
# Out:
#   manufacturer model  displ    Év  Henger       trans drv  cty  hwy fl  \
# 1         audi    a4    1.8  1999       4    auto(l5)   f   18   29  p
# 2         audi    a4    1.8  1999       4  manual(m5)   f   21   29  p
# 3         audi    a4    2.0  2008       4  manual(m6)   f   20   31  p
# 4         audi    a4    2.0  2008       4    auto(av)   f   21   30  p
# 5         audi    a4    2.8  1999       6    auto(l5)   f   16   26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %%
new_df = new_df.rename(mapper=str.strip, axis='columns')
new_df.head()
#oszlopnevkeben es elejen hatujan kivenni a space helyeket
# Out:
#   manufacturer model  displ    Év  Henger       trans drv  cty  hwy fl  \
# 1         audi    a4    1.8  1999       4    auto(l5)   f   18   29  p
# 2         audi    a4    1.8  1999       4  manual(m5)   f   21   29  p
# 3         audi    a4    2.0  2008       4  manual(m6)   f   20   31  p
# 4         audi    a4    2.0  2008       4    auto(av)   f   21   30  p
# 5         audi    a4    2.8  1999       6    auto(l5)   f   16   26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %%
cols = list(df.columns)

cols = (x.lower().strip() for x in cols)

df.columns = cols
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# ##DF Querying

# %%
admit_mask = df['cty'] < 19
admit_mask
# Out:
# 1       True
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 230    False
# 231    False
# 232     True
# 233     True
# 234     True
# Name: cty, Length: 234, dtype: bool

# %%
df.where(admit_mask).dropna().head()
# Out:
#   manufacturer       model  displ    year  cyl       trans drv   cty   hwy fl  \
# 1         audi          a4    1.8  1999.0  4.0    auto(l5)   f  18.0  29.0  p
# 5         audi          a4    2.8  1999.0  6.0    auto(l5)   f  16.0  26.0  p
# 6         audi          a4    2.8  1999.0  6.0  manual(m5)   f  18.0  26.0  p
# 7         audi          a4    3.1  2008.0  6.0    auto(av)   f  18.0  27.0  p
# 8         audi  a4 quattro    1.8  1999.0  4.0  manual(m5)   4  18.0  26.0  p
#
#      class
# 1  compact
# 5  compact
# 6  compact
# 7  compact
# 8  compact

# %%
df.where(admit_mask).head()
# Out:
#   manufacturer model  displ    year  cyl     trans  drv   cty   hwy   fl  \
# 1         audi    a4    1.8  1999.0  4.0  auto(l5)    f  18.0  29.0    p
# 2          NaN   NaN    NaN     NaN  NaN       NaN  NaN   NaN   NaN  NaN
# 3          NaN   NaN    NaN     NaN  NaN       NaN  NaN   NaN   NaN  NaN
# 4          NaN   NaN    NaN     NaN  NaN       NaN  NaN   NaN   NaN  NaN
# 5         audi    a4    2.8  1999.0  6.0  auto(l5)    f  16.0  26.0    p
#
#      class
# 1  compact
# 2      NaN
# 3      NaN
# 4      NaN
# 5  compact

# %%
df[df['cty'] < 19].head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 5         audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# 6         audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 7         audi          a4    3.1  2008    6    auto(av)   f   18   27  p
# 8         audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
#
#      class
# 1  compact
# 5  compact
# 6  compact
# 7  compact
# 8  compact

# %%
(df['cty'] < 19) & (df['cty'] > 17)
# Out:
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 230    False
# 231    False
# 232    False
# 233     True
# 234    False
# Name: cty, Length: 234, dtype: bool

# %%
df['cty'].gt(19) & df['cty'].lt(17)
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# Name: cty, Length: 234, dtype: bool

# %%
df['cty'].gt(19).lt(17)
#nem jo mert elosszor leszuri az egyiket majd utana meg a masikat
# Out:
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
#        ...
# 230    True
# 231    True
# 232    True
# 233    True
# 234    True
# Name: cty, Length: 234, dtype: bool

# %% [markdown]
# ## Indexing Data Frame

# %%
kf = pd.read_csv("predict.csv", index_col=0)
kf.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
kf = kf.set_index('SOP')
kf.head()
# atrakja za indexelo oszlopot
# Out:
#      GRE Score  TOEFL Score  University Rating  LOR   CGPA  Research  \
# SOP
# 4.5        337          118                  4   4.5  9.65         1
# 4.0        324          107                  4   4.5  8.87         1
# 3.0        316          104                  3   3.5  8.00         1
# 3.5        322          110                  3   2.5  8.67         1
# 2.0        314          103                  2   3.0  8.21         0
#
#      Chance of Admit
# SOP
# 4.5              0.92
# 4.0              0.76
# 3.0              0.72
# 3.5              0.80
# 2.0              0.65

# %%
kf = kf.reset_index()
kf.head()
# Out:
#    SOP  GRE Score  TOEFL Score  University Rating  LOR   CGPA  Research  \
# 0  4.5        337          118                  4   4.5  9.65         1
# 1  4.0        324          107                  4   4.5  8.87         1
# 2  3.0        316          104                  3   3.5  8.00         1
# 3  3.5        322          110                  3   2.5  8.67         1
# 4  2.0        314          103                  2   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df = pd.read_csv("census.csv")
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50])

# %%
df = df[df['SUMLEV'] == 50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
colums_to_keep = ['STNAME', 'CTYNAME', 'BIRTHS2021', 'BIRTHS2011']

df = df[colums_to_keep]
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
#       1 colums_to_keep = ['STNAME', 'CTYNAME', 'BIRTHS2021', 'BIRTHS2011']
# ----> 3 df = df[colums_to_keep]
#       4 df.head()
#
# File ~\PycharmProjects\datascience\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~\PycharmProjects\datascience\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %% [markdown]
# ## DF with Missing values

# %%
df = pd.read_csv("class_grades.csv")
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
mask = df.isnull()
mask
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0    False       False     False    False     False  False
# 1    False       False     False    False     False  False
# 2    False       False     False     True     False  False
# 3    False        True      True    False     False  False
# 4    False       False     False    False     False  False
# ..     ...         ...       ...      ...       ...    ...
# 94   False        True     False    False     False  False
# 95   False        True     False    False     False  False
# 96   False       False     False    False     False  False
# 97   False       False     False    False     False  False
# 98   False       False     False    False     False  False
#
# [99 rows x 6 columns]

# %%
df.fillna(0, inplace=True)
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
df = pd.read_csv('log.csv')
df.head(20)
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df = df.ffill()
df.head(20)
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6  False    10.0
# 2   1469974544  cheryl     intro.html                  9  False    10.0
# 3   1469974574  cheryl     intro.html                 10  False    10.0
# 4   1469977514     bob     intro.html                  1  False    10.0
# 5   1469977544     bob     intro.html                  1  False    10.0
# 6   1469977574     bob     intro.html                  1  False    10.0
# 7   1469977604     bob     intro.html                  1  False    10.0
# 8   1469974604  cheryl     intro.html                 11  False    10.0
# 9   1469974694  cheryl     intro.html                 14  False    10.0
# 10  1469974724  cheryl     intro.html                 15  False    10.0
# 11  1469974454     sue  advanced.html                 24  False    10.0
# ...

# %%
df = df.dfill().head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13372\2779363028.py in ?()
# ----> 1 df = df.dfill().head(20)
#
# ~\PycharmProjects\datascience\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dfill'

# %%
df = pd.DataFrame({'A':[1,2,2,3]
                  'B': [3,6,3,7,8]
})

# %% [markdown]
# ## DF manipulating Example

# %%
df = pd.read_csv('presidents.csv')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
df['First'] = df['President']
df['First'] = df['First'].replace("[].*","", regex=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# PatternError                              Traceback (most recent call last)
# Cell In[53], line 2
#       1 df['First'] = df['President']
# ----> 2 df['First'] = df['First'].replace("[].*","", regex=True)
#       3 df.head()
#
# File ~\PycharmProjects\datascience\.venv\Lib\site-packages\pandas\core\generic.py:7842, in NDFrame.replace(self, to_replace, value, inplace, regex)
#    7839     return self._replace_columnwise(mapping, inplace, regex)
#    7841 elif not is_list_like(value):  # NA -> 0
# -> 7842     regex = should_use_regex(regex, to_replace)
#    7843     if regex:
#    7844         new_data = self._mgr.replace_regex(
#    7845             to_replace=to_replace,
#    7846             value=value,
#    7847             inplace=inplace,
#    7848         )
#
# File ~\PycharmProjects\datascience\.venv\Lib\site-packages\pandas\core\array_algos\replace.py:39, in should_use_regex(regex, to_replace)
# ...

# %% [markdown]
# pip install lxml

# %%
url =
